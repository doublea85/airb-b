# %%
import pandas as pd
import sqlalchemy as db
import subprocess
import pymysql

# %%
reviews = pd.read_csv("http://data.insideairbnb.com/united-states/wa/seattle/2020-05-21/data/reviews.csv.gz", compression="gzip", low_memory=False)
planning = pd.read_csv("http://data.insideairbnb.com/united-states/wa/seattle/2020-05-21/data/calendar.csv.gz", compression="gzip", low_memory=False)
listings = pd.read_csv("http://data.insideairbnb.com/united-states/wa/seattle/2020-05-21/data/listings.csv.gz", compression="gzip", low_memory=False)

# %%
#df = pd.read_csv("/home/arcanum/projet_C_O/listings.csv.gz", compression='gzip', low_memory=False)

# %%
listings.head(6)
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2318  https://www.airbnb.com/rooms/2318  20200423041427   2020-04-23
# 1  6606  https://www.airbnb.com/rooms/6606  20200423041427   2020-04-23
# 2  9419  https://www.airbnb.com/rooms/9419  20200423041427   2020-04-23
# 3  9531  https://www.airbnb.com/rooms/9531  20200423041427   2020-04-23
# 4  9534  https://www.airbnb.com/rooms/9534  20200423041427   2020-04-23
# 5  9596  https://www.airbnb.com/rooms/9596  20200423041427   2020-04-23
#
#                                                 name  \
# 0  Casa Madrona - Urban Oasis 1 block from the park!
# 1                Fab, private seattle urban cottage!
# 2                Glorious sun room w/ memory foambed
# 3                The Adorable Sweet Orange Craftsman
# 4                   The Coolest Tangerine Dream MIL!
# 5         the down home , spacious, central and fab!
#
#                                              summary  \
# ...

# %%
list(listings.columns)
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
# ...

# %%
listings["host_id"].unique()
# Out:
# array([    2536,    14942,    30559, ..., 26003087, 35824164,  3198637])

# %%
host_2536 = listings[listings['host_id'] == 2536]
host_2536[['host_id', 'host_name', 'host_since', 'listing_url']]
# Out:
#       host_id host_name  host_since                            listing_url
# 0        2536     Megan  2008-08-26      https://www.airbnb.com/rooms/2318
# 4826     2536     Megan  2008-08-26  https://www.airbnb.com/rooms/30013204

# %%
hosts = listings.drop_duplicates(subset ="host_id", keep = 'first', inplace = False)

# %%
hosts
# Out:
#             id                            listing_url       scrape_id  \
# 0         2318      https://www.airbnb.com/rooms/2318  20200423041427
# 1         6606      https://www.airbnb.com/rooms/6606  20200423041427
# 2         9419      https://www.airbnb.com/rooms/9419  20200423041427
# 3         9531      https://www.airbnb.com/rooms/9531  20200423041427
# 6         9909      https://www.airbnb.com/rooms/9909  20200423041427
# ...        ...                                    ...             ...
# 7223  43187774  https://www.airbnb.com/rooms/43187774  20200423041427
# 7227  43190704  https://www.airbnb.com/rooms/43190704  20200423041427
# 7229  43222285  https://www.airbnb.com/rooms/43222285  20200423041427
# 7235  43257978  https://www.airbnb.com/rooms/43257978  20200423041427
# 7236  43258878  https://www.airbnb.com/rooms/43258878  20200423041427
#
#      last_scraped                                               name  \
# ...

# %%
listings.shape
# Out:
# (7237, 106)

# %% [markdown]
# # CREATING TABLES

# %%
# host
host = pd.DataFrame(hosts[["host_id","host_since","host_name"]])

# property
property = pd.DataFrame(listings[["accommodates","bathrooms","bedrooms","beds","bed_type","room_type","square_feet","longitude","latitude"]])

# location
location = pd.DataFrame(listings[["street","state","country","zipcode","neighborhood_overview","neighbourhood_cleansed","city"]])
price = pd.DataFrame(listings[["price","weekly_price","monthly_price"]])

# listing
listing = pd.DataFrame(listings[["id","name","description","summary","notes"]])
listing.rename(columns={'name':'l_name','description':'l_description'},inplace=True)

#calendar
calendar = planning.rename(columns={'date':'p_date'}, inplace=False)


############ EXPORTING DATAFRAMES #####################

# host
host.to_csv("/home/arcanum/projet_C_O/tables/host1.csv", index=False)

# property
property.to_csv("/home/arcanum/projet_C_O/tables/property.csv", index=False)

# location
location.to_csv("/home/arcanum/projet_C_O/tables/location1.csv", index=False)

# price
price.to_csv("/home/arcanum/projet_C_O/tables/price.csv", index=False)

# listings
listing.to_csv("/home/arcanum/projet_C_O/tables/listing.csv", index=False)

# calendar
calendar.to_csv("/home/arcanum/projet_C_O/tables/calendar.csv", index=False)

# %%
#create engine
from sqlalchemy import create_engine
# create sqlalchemy engine
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw="Vazapoto85@",
                               db="test"))
# create connection
con = pymysql.connect(host='localhost',
                             user='root',
                             password='Vazapoto85@',
                             db='test')
con

# %%
# host
host.to_sql(name='hoste', con=engine, if_exists='append', index=False)

# property
properties.to_sql(name='property', con=engine, if_exists='append', index=False)

# listings
listing.to_sql(name='listing', con=engine, if_exists='append', index=False)

# location
location.to_sql(name='location', con=engine, if_exists='append', index=False)

# price
price.to_sql(name='price', con=engine, if_exists='append', index=False)

# calendar
host.to_sql(name='hoste', con=engine, if_exists='append', index=False)

# planning
planning.to_sql(name='calendar', con=engine, if_exists='append', index=False)

# %% [markdown]
# # Importing data into sql

# %%
command = "mysql -u root --password=Vazapoto85@ air < mcd.sql".split()
p = subprocess.Popen(command, stdout=subprocess.PIPE)
p.communicate()  # you can see if errors are returned
# Out:
# (b"mysql  Ver 8.0.20 for Linux on x86_64 (MySQL Community Server - GPL)\nCopyright (c) 2000, 2020, Oracle and/or its affiliates. All rights reserved.\n\nOracle is a registered trademark of Oracle Corporation and/or its\naffiliates. Other names may be trademarks of their respective\nowners.\n\nUsage: mysql [OPTIONS] [database]\n  -?, --help          Display this help and exit.\n  -I, --help          Synonym for -?\n  --auto-rehash       Enable automatic rehashing. One doesn't need to use\n                      'rehash' to get table and field completion, but startup\n                      and reconnecting may take a longer time. Disable with\n                      --disable-auto-rehash.\n                      (Defaults to on; use --skip-auto-rehash to disable.)\n  -A, --no-auto-rehash \n                      No automatic rehashing. One has to use 'rehash' to get\n                      table and field completion. This gives a quicker start of\n                      mysql and disables re
# ...

# %%
host = pd.DataFrame(listings[["host_id","host_since","host_name"]])
host.isna().sum()
#host.to_csv("/home/arcanum/projet_C_O/tables/host1.csv", index=False)
# Out:
# host_id       0
# host_since    0
# host_name     0
# dtype: int64

# %%
property = pd.DataFrame(listings[["accommodates","bathrooms","bedrooms","beds","bed_type","room_type","square_feet","longitude","latitude"]])
property.isna().sum()
#property.to_csv("/home/arcanum/projet_C_O/tables/property.csv", index=False)
# Out:
# accommodates       0
# bathrooms          1
# bedrooms           5
# beds              13
# bed_type           0
# room_type          0
# square_feet     6926
# longitude          0
# latitude           0
# dtype: int64

# %%
location = pd.DataFrame(listings[["street","state","country","zipcode","neighborhood_overview","neighbourhood_cleansed","city"]])
location.isna().sum()
#location.to_csv("/home/arcanum/projet_C_O/tables/location1.csv", index=False)
# Out:
# street                       0
# state                        1
# country                      0
# zipcode                     31
# neighborhood_overview     2003
# neighbourhood_cleansed       0
# city                         0
# dtype: int64

# %%
#review = pd.DataFrame(df[["review_scores_rating","first_review","last_review"]])
#review.to_csv("/home/arcanum/projet_C_O/tables/review.csv", index=False)

# %%
price = pd.DataFrame(listings[["price","weekly_price","monthly_price"]])
price.to_csv("/home/arcanum/projet_C_O/tables/price.csv", index=False)

# %%
listing = pd.DataFrame(listings[["id","name","description","summary","notes"]])
listing.rename(columns={'name':'l_name','description':'l_description'},inplace=True)
listing.to_csv("/home/arcanum/projet_C_O/tables/listing.csv", index=False)

# %%
#palnning = pd.read_csv("/home/arcanum/projet_C_O/calendar.csv.gz", compression='gzip', low_memory=False)
#palnning.head()

# %%
calendar = planning.rename(columns={'date':'p_date'}, inplace=False)
calendar.to_csv("/home/arcanum/projet_C_O/tables/calendar.csv", index=False)

# %%
#review = pd.read_csv("/home/arcanum/projet_C_O/reviews.csv.gz", compression='gzip', low_memory=False)
#review

# %%
reviews.head()
# Out:
#    listing_id         id      r_date  reviewer_id reviewer_name  \
# 0        2318        146  2008-09-15         2451         Kevin
# 1        2318  126302712  2017-01-10     12332845       Jessica
# 2        2318  140977084  2017-04-01      4789466          Ivan
# 3        2318  147262504  2017-04-25     55817131          Mike
# 4        2318  161806368  2017-06-18    113604590          Pete
#
#                                             comments  review_scores_rating  \
# 0        1000 times better than staying at a hotel.                  100.0
# 1  Our family (two couples, a two year old and an...                  92.0
# 2  Top of the list locations we have stayed at! T...                  93.0
# 3  SUCH an awesome place. Very clean, quiet and s...                 100.0
# 4  We flew quite a distance to be at our only dau...                 100.0
#
#   first_review last_review
# 0   2008-09-15  2020-02-01
# 1   2009-07-17  2019-09-28
# 2   2010-07-30  2019-12-27
# ...

# %%
reviews[["review_scores_rating","first_review","last_review"]] = listings[["review_scores_rating","first_review","last_review"]]
reviews.rename(columns={'date':'r_date'},inplace=True)
reviews.to_csv("/home/arcanum/projet_C_O/tables/review.csv", index=False)

# %%
import mysql.connector

file = open('/home/arcanum/Bureau/mcd.sql')
sql = file.read()

cnx = mysql.connector.connect(user='root', password='Vazapoto85@', host='localhost', database='test')
cursor = cnx.cursor()

for result in cursor.execute(sql, multi=True):
  if result.with_rows:
    print("Rows produced by statement '{}':".format(
      result.statement))
    print(result.fetchall())
  else:
    print("Number of rows affected by statement '{}': {}".format(
      result.statement, result.rowcount))

cnx.close()
# Out:
# Number of rows affected by statement 'Drop table if exists hoste;
# create table if not exists hoste(
# host_id  INT PRIMARY KEY,
# host_since date,
# host_name varchar(45));
#
#
#
# Drop table if exists location;
# Create table if not exists location(
# location_id INT PRIMARY KEY auto_increment,
# street varchar(100),
# state varchar(50),
# country varchar(30),
# zipcode varchar(50),
# neighborhood_overview text,
# neighbourhood_cleansed text,
# city varchar(30));
#
#
#
# Drop table if exists property;
# Create table if not exists property(
# property_id INT PRIMARY KEY not null auto_increment,
# accommodates INT,
# bathrooms varchar(10),
# bedrooms varchar(10),
# beds varchar(10),
# bed_type varchar(30),
# room_type varchar(30),
# square_feet varchar(10),
# longitude DECIMAL,
# latitude DECIMAL);
#
#
#
# Drop table if exists price;
# Create table if not exists price(
# price_id INT PRIMARY KEY not null auto_increment,
# price varchar(30),
# weekly_price varchar(10),
# ...
